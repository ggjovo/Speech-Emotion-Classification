# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier

import joblib
import json

# %% [markdown]
# **IMPORTING DATA**
# - Scaled full data
# - Scaled PCA data
# - Scaled LDA data

# %%
DATA_PATH = os.path.join("../data/processed/")

# %%
# Loading scaled data
X_train_scaled = pd.read_csv(os.path.join(DATA_PATH, "X_train_scaled.csv"))
X_test_scaled = pd.read_csv(os.path.join(DATA_PATH, "X_test_scaled.csv"))

# Loading pca data
X_train_pca = pd.read_csv(os.path.join(DATA_PATH, "X_train_pca.csv"))
X_test_pca = pd.read_csv(os.path.join(DATA_PATH, "X_test_pca.csv"))

# Loading lda data
X_train_lda = pd.read_csv(os.path.join(DATA_PATH, "X_train_lda.csv"))
X_test_lda = pd.read_csv(os.path.join(DATA_PATH, "X_test_lda.csv"))

# Loading data labels
y_train = pd.read_csv(os.path.join(DATA_PATH, "y_train.csv")).to_numpy().ravel()
y_test = pd.read_csv(os.path.join(DATA_PATH, "y_test.csv")).to_numpy().ravel()

# %%
# Initialize parameters grid
param_grid = {
    'n_estimators': [50, 100, 200, 500],  # Number of trees in the forest
    'criterion': ['gini'],  # Split criterion
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10]  # Minimum number of samples required to split an internal node
}

# %% [markdown]
# **TRAINING RANDOM FOREST ON SCALED DATA**

# %%
# Initialize classifier
rf = RandomForestClassifier()

# Initialize GridSearchCV
grid_search_scaled = GridSearchCV(rf, param_grid, cv=KFold(n_splits=5, shuffle=True), scoring='accuracy', verbose=3, n_jobs=-1)

# Fit the model
grid_search_scaled.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=50;, score=0.835 total time=   7.6s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=50;, score=0.850 total time=   8.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=50;, score=0.833 total time=   8.1s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=50;, score=0.826 total time=   8.1s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=50;, score=0.829 total time=   8.4s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=100;, score=0.846 total time=  14.7s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=100;, score=0.854 total time=  15.1s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=100;, score=0.838 total time=  15.8s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=100;, score=0.854 total time=  15.4s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=100;, score=0.862 total time=  15.8s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=200;, score=0.875 total time=  30.5s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=200;, score=0.857 total time=  30.9s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=200;, score=0.857 total time=  32.3s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=200;, score=0.866 total time=  31.8s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=200;, score=0.858 total time=  31.8s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=50;, score=0.843 total time=   8.8s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=50;, score=0.831 total time=   8.4s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=50;, score=0.827 total time=   8.7s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=50;, score=0.833 total time=   8.8s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=50;, score=0.837 total time=   7.7s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=100;, score=0.867 total time=  16.5s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=100;, score=0.852 total time=  16.9s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=100;, score=0.853 total time=  16.6s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=100;, score=0.841 total time=  17.3s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=100;, score=0.864 total time=  16.9s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=500;, score=0.877 total time= 1.4min
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=500;, score=0.868 total time= 1.5min
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=500;, score=0.864 total time= 1.5min
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=200;, score=0.880 total time=  34.7s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=200;, score=0.856 total time=  34.8s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=500;, score=0.871 total time= 1.5min
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=2, n_estimators=500;, score=0.876 total time= 1.5min
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=200;, score=0.855 total time=  35.4s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=200;, score=0.875 total time=  35.9s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=50;, score=0.843 total time=   8.4s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=50;, score=0.826 total time=   8.9s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=50;, score=0.826 total time=   8.8s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=200;, score=0.863 total time=  34.9s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=50;, score=0.830 total time=   8.6s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=50;, score=0.832 total time=   8.7s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=100;, score=0.852 total time=  16.9s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=100;, score=0.840 total time=  17.6s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=100;, score=0.853 total time=  18.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=100;, score=0.864 total time=  17.7s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=100;, score=0.846 total time=  17.4s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=500;, score=0.879 total time= 1.3min
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=500;, score=0.862 total time= 1.4min
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=200;, score=0.878 total time=  35.4s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=500;, score=0.863 total time= 1.4min
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=500;, score=0.872 total time= 1.4min
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=5, n_estimators=500;, score=0.875 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=200;, score=0.837 total time=  33.3s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=200;, score=0.856 total time=  33.6s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=200;, score=0.860 total time=  33.6s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=50;, score=0.807 total time=   7.5s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=50;, score=0.803 total time=   6.7s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=200;, score=0.852 total time=  33.6s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=50;, score=0.801 total time=   7.1s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=50;, score=0.799 total time=   6.3s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=50;, score=0.818 total time=   7.1s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100;, score=0.835 total time=  14.3s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100;, score=0.813 total time=  12.6s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100;, score=0.824 total time=  13.7s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100;, score=0.828 total time=  14.3s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100;, score=0.833 total time=  13.8s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200;, score=0.838 total time=  25.3s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=500;, score=0.875 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200;, score=0.815 total time=  28.5s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200;, score=0.828 total time=  28.8s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=500;, score=0.862 total time= 1.4min
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=500;, score=0.866 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=500;, score=0.858 total time= 1.4min
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=500;, score=0.856 total time= 1.5min
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200;, score=0.834 total time=  27.3s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=50;, score=0.812 total time=   7.6s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=50;, score=0.801 total time=   6.9s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=50;, score=0.800 total time=   7.5s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200;, score=0.833 total time=  27.7s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=50;, score=0.808 total time=   7.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=50;, score=0.806 total time=   7.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100;, score=0.822 total time=  13.1s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100;, score=0.810 total time=  13.2s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100;, score=0.809 total time=  13.2s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100;, score=0.813 total time=  13.7s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100;, score=0.846 total time=  13.7s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=500;, score=0.844 total time= 1.1min
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200;, score=0.832 total time=  27.1s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=500;, score=0.834 total time= 1.2min
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=500;, score=0.826 total time= 1.1min
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=500;, score=0.823 total time= 1.2min
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=500;, score=0.847 total time= 1.1min
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200;, score=0.831 total time=  27.6s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200;, score=0.819 total time=  25.8s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=50;, score=0.822 total time=   6.2s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=50;, score=0.808 total time=   6.2s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200;, score=0.836 total time=  27.3s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200;, score=0.834 total time=  29.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=50;, score=0.819 total time=   6.6s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=50;, score=0.806 total time=   6.3s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=50;, score=0.808 total time=   7.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100;, score=0.832 total time=  12.7s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100;, score=0.815 total time=  12.3s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100;, score=0.813 total time=  13.5s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100;, score=0.823 total time=  12.5s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100;, score=0.832 total time=  12.9s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500;, score=0.825 total time= 1.1min
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500;, score=0.845 total time= 1.1min
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500;, score=0.835 total time= 1.1min
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500;, score=0.833 total time= 1.1min
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200;, score=0.826 total time=  27.6s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500;, score=0.845 total time= 1.1min
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200;, score=0.810 total time=  25.1s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200;, score=0.822 total time=  24.8s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=50;, score=0.847 total time=   8.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200;, score=0.837 total time=  24.6s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200;, score=0.836 total time=  25.9s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=50;, score=0.829 total time=   8.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=50;, score=0.848 total time=   7.9s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=50;, score=0.847 total time=   8.8s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=50;, score=0.830 total time=   7.7s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100;, score=0.874 total time=  15.7s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100;, score=0.851 total time=  17.6s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100;, score=0.856 total time=  16.2s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100;, score=0.861 total time=  15.7s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=500;, score=0.820 total time= 1.1min
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=500;, score=0.848 total time= 1.1min
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100;, score=0.863 total time=  16.7s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=500;, score=0.842 total time= 1.1min
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=500;, score=0.833 total time= 1.1min
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=500;, score=0.822 total time= 1.1min
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200;, score=0.881 total time=  32.3s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200;, score=0.854 total time=  33.1s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200;, score=0.869 total time=  34.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200;, score=0.871 total time=  34.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200;, score=0.862 total time=  35.3s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=50;, score=0.838 total time=   8.6s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=50;, score=0.827 total time=   8.4s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=50;, score=0.825 total time=   8.6s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=50;, score=0.840 total time=   8.1s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=50;, score=0.831 total time=   8.4s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.864 total time=  17.1s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.846 total time=  17.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.848 total time=  16.8s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.865 total time=  17.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.855 total time=  17.3s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500;, score=0.879 total time= 1.4min
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500;, score=0.865 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500;, score=0.864 total time= 1.4min
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.870 total time=  33.9s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500;, score=0.875 total time= 1.5min
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.856 total time=  35.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500;, score=0.869 total time= 1.4min
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.851 total time=  35.8s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.866 total time=  31.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.866 total time=  34.3s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=50;, score=0.841 total time=   8.5s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=50;, score=0.834 total time=   8.1s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=50;, score=0.812 total time=   7.9s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=50;, score=0.843 total time=   8.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=50;, score=0.823 total time=   8.3s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100;, score=0.849 total time=  16.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100;, score=0.851 total time=  17.3s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100;, score=0.841 total time=  15.5s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100;, score=0.857 total time=  15.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100;, score=0.850 total time=  17.1s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=500;, score=0.883 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=500;, score=0.859 total time= 1.5min
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200;, score=0.864 total time=  33.7s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200;, score=0.848 total time=  31.6s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=500;, score=0.872 total time= 1.5min
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=500;, score=0.868 total time= 1.4min
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=500;, score=0.869 total time= 1.5min
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200;, score=0.862 total time=  35.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=50;, score=0.843 total time=   8.9s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200;, score=0.861 total time=  35.2s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200;, score=0.862 total time=  33.3s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=50;, score=0.818 total time=   9.1s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=50;, score=0.823 total time=   8.7s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=50;, score=0.854 total time=   9.4s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=50;, score=0.842 total time=   9.2s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100;, score=0.853 total time=  17.2s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100;, score=0.848 total time=  18.1s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100;, score=0.855 total time=  17.4s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100;, score=0.870 total time=  17.7s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100;, score=0.853 total time=  17.7s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=500;, score=0.877 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=500;, score=0.853 total time= 1.4min
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=500;, score=0.871 total time= 1.3min
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=500;, score=0.857 total time= 1.4min
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200;, score=0.875 total time=  35.1s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=500;, score=0.862 total time= 1.4min
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200;, score=0.853 total time=  33.9s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200;, score=0.862 total time=  34.8s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200;, score=0.869 total time=  35.2s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=50;, score=0.843 total time=   8.8s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200;, score=0.862 total time=  33.9s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=50;, score=0.842 total time=   8.5s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=50;, score=0.828 total time=   8.3s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=50;, score=0.841 total time=   8.5s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=50;, score=0.851 total time=   8.3s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.858 total time=  16.1s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.853 total time=  17.8s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.848 total time=  17.3s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.860 total time=  15.8s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.855 total time=  17.8s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=500;, score=0.881 total time= 1.5min
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=500;, score=0.864 total time= 1.5min
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=500;, score=0.863 total time= 1.4min
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=500;, score=0.874 total time= 1.4min
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.868 total time=  34.7s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=500;, score=0.873 total time= 1.5min
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.859 total time=  35.2s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.873 total time=  34.1s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=50;, score=0.843 total time=   8.3s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.873 total time=  32.8s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.862 total time=  34.7s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=50;, score=0.830 total time=   8.4s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=50;, score=0.850 total time=   9.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=50;, score=0.843 total time=   8.4s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=50;, score=0.818 total time=   8.2s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100;, score=0.853 total time=  17.1s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100;, score=0.837 total time=  16.7s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100;, score=0.854 total time=  15.5s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100;, score=0.852 total time=  16.9s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100;, score=0.844 total time=  17.1s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=500;, score=0.879 total time= 1.5min
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=500;, score=0.858 total time= 1.4min
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200;, score=0.866 total time=  32.4s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=500;, score=0.862 total time= 1.5min
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=500;, score=0.871 total time= 1.4min
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=500;, score=0.883 total time= 1.5min
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200;, score=0.857 total time=  31.9s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200;, score=0.859 total time=  34.9s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200;, score=0.857 total time=  33.7s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200;, score=0.866 total time=  32.1s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=500;, score=0.877 total time= 1.1min
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=500;, score=0.850 total time= 1.1min
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=500;, score=0.863 total time= 1.1min
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=500;, score=0.862 total time= 1.1min
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=500;, score=0.871 total time= 1.2min
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200, 500]},
#              scoring='accuracy', verbose=3)

# %%
best_params = grid_search_scaled.best_params_
print("Best Parameters:", best_params)

with open('../models/rf/scaled.csv', 'w') as f:
    json.dump(best_params, f)
    
#TODO save model and save params
# Get the best model
best_rf = grid_search_scaled.best_estimator_

joblib.dump(best_rf, "../models/rf/scaled.pkl")

# Print mean validation score for the best model
best_score = grid_search_scaled.best_score_
print("Best Model Validation Score:", best_score)

# Predict on the test set
y_pred_rf_scaled = best_rf.predict(X_test_scaled)

# Calculate accuracy on the test set
accuracy_scaled = accuracy_score(y_test, y_pred_rf_scaled)
print("Test Accuracy:", accuracy_scaled)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 500}
# Best Model Validation Score: 0.8715406672794547
# Test Accuracy: 0.6090561224489796

# %%
pd.DataFrame(y_pred_rf_scaled, columns=["y_pred"]).to_csv("../results/rf/scaled.csv")

# %% [markdown]
# **TRAINING RANDOM FOREST ON PCA DATA**

# %%
# Initialize classifier
rf = RandomForestClassifier()

# Initialize GridSearchCV
grid_search_pca = GridSearchCV(rf, param_grid, cv=KFold(n_splits=5, shuffle=True), scoring='accuracy', verbose=1, n_jobs=-1)

# Fit the model
grid_search_pca.fit(X_train_pca, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200, 500]},
#              scoring='accuracy', verbose=1)

# %%
best_params = grid_search_pca.best_params_
print("Best Parameters:", best_params)

with open('../models/rf/pca.csv', 'w') as f:
    json.dump(best_params, f)

# Get the best model
best_rf = grid_search_pca.best_estimator_

joblib.dump(best_rf, "../models/rf/pca.pkl")

# Print mean validation score for the best model
best_score = grid_search_pca.best_score_
print("Best Model Validation Score:", best_score)

# Predict on the test set
y_pred_rf_pca = best_rf.predict(X_test_pca)

# Calculate accuracy on the test set
accuracy_pca = accuracy_score(y_test, y_pred_rf_pca)
print("Test Accuracy:", accuracy_pca)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 500}
# Best Model Validation Score: 0.7666177535410492
# Test Accuracy: 0.5535714285714286

# %%
pd.DataFrame(y_pred_rf_pca, columns=["y_pred"]).to_csv("../results/rf/pca.csv")

# %% [markdown]
# **TRAINING RANDOM FOREST ON LDA DATA**

# %%
# Initialize classifier
rf = RandomForestClassifier()

# Initialize GridSearchCV
grid_search_lda = GridSearchCV(rf, param_grid, cv=KFold(n_splits=5, shuffle=True), scoring='accuracy', verbose=1, n_jobs=-1)

# Fit the model
grid_search_lda.fit(X_train_lda, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200, 500]},
#              scoring='accuracy', verbose=1)

# %%
best_params = grid_search_lda.best_params_
print("Best Parameters:", best_params)

with open('../models/rf/lda.csv', 'w') as f:
    json.dump(best_params, f)

# Get the best model
best_rf = grid_search_lda.best_estimator_

joblib.dump(best_rf, "../models/rf/lda.pkl")

# Print mean validation score for the best model
best_score = grid_search_lda.best_score_
print("Best Model Validation Score:", best_score)

# Predict on the test set
y_pred_rf_lda = best_rf.predict(X_test_lda)

# Calculate accuracy on the test set
accuracy_lda = accuracy_score(y_test, y_pred_rf_lda)
print("Test Accuracy:", accuracy_lda)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 500}
# Best Model Validation Score: 0.9080055398236654
# Test Accuracy: 0.5210459183673469

# %%
pd.DataFrame(y_pred_rf_lda, columns=["y_pred"]).to_csv("../results/rf/lda.csv")
