# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

from sklearn.neural_network import MLPClassifier

import joblib
import json

# %% [markdown]
# **IMPORTING DATA**
# - Scaled full data
# - Scaled PCA data
# - Scaled LDA data

# %%
DATA_PATH = os.path.join("../data/processed/")

# %%
# Loading scaled data
X_train_scaled = pd.read_csv(os.path.join(DATA_PATH, "X_train_scaled.csv"))
X_test_scaled = pd.read_csv(os.path.join(DATA_PATH, "X_test_scaled.csv"))

# Loading pca data
X_train_pca = pd.read_csv(os.path.join(DATA_PATH, "X_train_pca.csv"))
X_test_pca = pd.read_csv(os.path.join(DATA_PATH, "X_test_pca.csv"))

# Loading lda data
X_train_lda = pd.read_csv(os.path.join(DATA_PATH, "X_train_lda.csv"))
X_test_lda = pd.read_csv(os.path.join(DATA_PATH, "X_test_lda.csv"))

# Loading data labels
y_train = pd.read_csv(os.path.join(DATA_PATH, "y_train.csv")).to_numpy().ravel()
y_test = pd.read_csv(os.path.join(DATA_PATH, "y_test.csv")).to_numpy().ravel()

# %% [markdown]
# **MLP ARCHITECTURE**
# - reference to paper: <https://pubmed.ncbi.nlm.nih.gov/36236658/>
# - MLP has 3 hidden layers:
#     1) (n_features + n_classes)/2 neurons
#     2) 32 neurons
#     3) 16 neurons

# %%
n_features = len(X_test_scaled.columns)
n_classes = 5
first_layer = (n_features + n_classes) // 2

# %% [markdown]
# **DEFINING HYPER-PARAMETERS FOR TUNING**

# %%
param_grid = {
    'hidden_layer_sizes': [(first_layer, 32, 16)], # MLP architecture from mentioned paper
    'activation': ['tanh', 'relu'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'adaptive'],
    'max_iter' : [750]
}

# %% [markdown]
# **TRAINING MLP ON SCALED DATA**

# %%
# Initialize classifier
mlp = MLPClassifier()

# Initialize GridSearchCV
grid_search_scaled = GridSearchCV(mlp, param_grid, cv=KFold(n_splits=5, shuffle=True), scoring='accuracy', verbose=3, n_jobs=-1)

# Fit the model
grid_search_scaled.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 3/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.899 total time= 2.0min
# [CV 4/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.902 total time= 2.1min
# [CV 1/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.890 total time= 2.2min
# [CV 5/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.905 total time= 2.2min
# [CV 2/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.898 total time= 2.4min
# [CV 1/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.896 total time= 2.2min
# [CV 2/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.902 total time= 2.2min
# [CV 3/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.917 total time= 2.1min
# [CV 5/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.905 total time= 2.2min
# [CV 4/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.904 total time= 2.2min
# [CV 1/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.848 total time= 7.9min
# [CV 2/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.857 total time= 8.2min
# [CV 3/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.869 total time= 8.3min
# [CV 4/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.867 total time= 7.7min
# [CV 5/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.847 total time= 7.8min
# [CV 1/5] END activation=tanh, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.894 total time= 2.0min
# [CV 2/5] END activation=tanh, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.887 total time= 2.2min
# [CV 3/5] END activation=tanh, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.909 total time= 2.3min
# [CV 4/5] END activation=tanh, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.906 total time= 2.3min
# [CV 1/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.849 total time= 9.5min
# [CV 5/5] END activation=tanh, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.891 total time= 2.2min
# [CV 2/5] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0
5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.899 total time= 1.4min
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.903 total time= 1.5min
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.901 total time= 1.5min
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.867 total time= 5.2min
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.907 total time= 1.5min
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.905 total time= 1.4min
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.864 total time= 5.2min
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.873 total time= 5.2min
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.856 total time= 5.0min
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.867 total time= 5.8min
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.867 total time= 6.7min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.868 total time= 5.5min
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.853 total time= 6.6min
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.875 total time= 6.9min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.883 total time= 5.2min
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.874 total time= 7.1min
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.865 total time= 7.0min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.905 total time= 5.4min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.887 total time= 5.1min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.857 total time= 4.8min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.868 total time= 5.0min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=adam;, score=0.918 total time= 5.6min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.868 total time= 5.0min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.876 total time= 5.3min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=500, solver=sgd;, score=0.879 total time= 5.4min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.879 total time= 5.9min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.896 total time= 4.7min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.890 total time= 5.0min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.900 total time= 5.0min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=adam;, score=0.907 total time= 5.3min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.857 total time= 5.6min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.869 total time= 5.9min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.881 total time= 5.6min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.876 total time= 4.6min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=500, solver=sgd;, score=0.859 total time= 2.9min
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.001, 0.01],
#                          'hidden_layer_sizes': [(496, 32, 16)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'max_iter': [500], 'solver': ['adam', 'sgd']},
#              scoring='accuracy', verbose=3)

# %%
best_params = grid_search_scaled.best_params_
print("Best Parameters:", best_params)

with open('../models/mlp/scaled.csv', 'w') as f:
    json.dump(best_params, f)

# Get the best model
best_mlp = grid_search_scaled.best_estimator_

joblib.dump(best_mlp, "../models/mlp/scaled.pkl")

# Print mean validation score for the best model
best_score = grid_search_scaled.best_score_
print("Best Model Validation Score:", best_score)

# Predict on the test set
y_pred_mlp_scaled = best_mlp.predict(X_test_scaled)

# Calculate accuracy on the test set
accuracy_scaled = accuracy_score(y_test, y_pred_mlp_scaled)
print("Test Accuracy:", accuracy_scaled)
# Out:
# Best Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (496, 32, 16), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# Best Model Validation Score: 0.9048565512674133
# Test Accuracy: 0.5459183673469388

# %%
pd.DataFrame(y_pred_mlp_scaled, columns=["y_pred"]).to_csv("../results/mlp/scaled.csv")

# %% [markdown]
# **TRAINING MLP ON PCA DATA**

# %%
# Initialize classifier
mlp = MLPClassifier()

# Initialize GridSearchCV
grid_search_pca = GridSearchCV(mlp, param_grid, cv=KFold(n_splits=5, shuffle=True), scoring='accuracy', verbose=3, n_jobs=-1)

# Fit the model
grid_search_pca.fit(X_train_pca, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV
5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.887 total time=  43.3s
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.870 total time=  43.9s
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.875 total time=  42.9s
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.885 total time=  43.0s
# [CV 2/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.872 total time= 3.9min
# [CV 1/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.844 total time= 4.1min
# [CV 5/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.874 total time= 3.7min
# [CV 3/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.853 total time= 4.0min
# [CV 4/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.858 total time= 4.0min
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.859 total time=  39.3s
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.888 total time=  43.8s
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.860 total time= 2.9min
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.863 total time=  44.8s
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.863 total time= 2.8min
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.889 total time=  41.2s
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.859 total time= 2.8min
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.877 total time=  43.8s
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.876 total time= 3.0min
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.857 total time= 3.2min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.868 total time= 2.0min
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.872 total time= 3.8min
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.848 total time= 4.0min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.892 total time= 2.1min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.883 total time= 2.0min
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.864 total time= 4.3min
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.876 total time= 3.8min
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.860 total time= 4.0min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.879 total time= 2.1min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.891 total time= 2.2min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.870 total time= 2.1min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.845 total time= 2.8min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.868 total time= 2.7min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.897 total time= 2.1min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.858 total time= 3.1min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.857 total time= 3.1min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.863 total time= 3.3min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.895 total time= 2.2min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.888 total time= 2.1min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.893 total time= 2.0min
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.843 total time= 2.9min
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.871 total time= 2.8min
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.863 total time= 3.1min
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.876 total time= 2.7min
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.871 total time= 2.8min
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.001, 0.01],
#                          'hidden_layer_sizes': [(496, 32, 16)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'max_iter': [750], 'solver': ['adam', 'sgd']},
#              scoring='accuracy', verbose=3)

# %%
best_params = grid_search_pca.best_params_
print("Best Parameters:", best_params)

with open('../models/mlp/pca.csv', 'w') as f:
    json.dump(best_params, f)

# Get the best model
best_mlp = grid_search_pca.best_estimator_

joblib.dump(best_mlp, "../models/mlp/pca.pkl")

# Print mean validation score for the best model
best_score = grid_search_pca.best_score_
print("Best Model Validation Score:", best_score)

# Predict on the test set
y_pred_mlp_pca = best_mlp.predict(X_test_pca)

# Calculate accuracy on the test set
accuracy_pca = accuracy_score(y_test, y_pred_mlp_pca)
print("Test Accuracy:", accuracy_pca)
# Out:
# Best Parameters: {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (496, 32, 16), 'learning_rate': 'adaptive', 'max_iter': 750, 'solver': 'adam'}
# Best Model Validation Score: 0.8886132716698197
# Test Accuracy: 0.5752551020408163

# %%
pd.DataFrame(y_pred_mlp_pca, columns=["y_pred"]).to_csv("../results/mlp/pca.csv")

# %% [markdown]
# **TRAINING MLP ON LDA DATA**

# %%
# NOTE: Few models could not converge

# %%
# Initialize classifier
mlp = MLPClassifier()

# Initialize GridSearchCV
grid_search_lda = GridSearchCV(mlp, param_grid, cv=KFold(n_splits=5, shuffle=True), scoring='accuracy', verbose=3, n_jobs=-1)

# Fit the model
grid_search_lda.fit(X_train_lda, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV
5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.912 total time=  24.9s
# [CV 2/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.911 total time=  30.6s
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.904 total time=  18.6s
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.917 total time=   5.8s
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.897 total time=  13.7s
# [CV 3/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.905 total time=  37.3s
# [CV 4/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.920 total time=  37.3s
# [CV 1/5] END activation=relu, alpha=0.0001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.914 total time=  44.9s
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.915 total time=   6.8s
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.907 total time=  27.4s
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.911 total time=  31.0s
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.904 total time=  29.4s
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.906 total time=  34.9s
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.923 total time=   6.2s
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.921 total time=  32.6s
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.887 total time=  19.7s
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.910 total time=  27.3s
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.893 total time=  34.8s
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.905 total time=  17.6s
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.903 total time=   9.9s
# [CV 2/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.911 total time=  25.9s
# [CV 1/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.911 total time=  33.2s
# [CV 3/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.904 total time=  30.3s
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.919 total time=   9.4s
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.898 total time=  34.1s
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.902 total time=  11.5s
# [CV 4/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.919 total time=  30.7s
# [CV 5/5] END activation=relu, alpha=0.001, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.908 total time=  38.9s
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.913 total time=  10.8s
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=adam;, score=0.908 total time=  21.4s
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.903 total time=  20.8s
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.923 total time=  20.8s
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.912 total time=  22.9s
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.905 total time=  13.0s
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.905 total time=  25.6s
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.907 total time=  10.8s
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=constant, max_iter=750, solver=sgd;, score=0.912 total time=  31.3s
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.896 total time=  22.5s
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=adam;, score=0.910 total time=  20.0s
# [CV 2/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.907 total time=  23.5s
# [CV 1/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.912 total time=  26.5s
# [CV 4/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.921 total time=  23.2s
# [CV 3/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.902 total time=  25.6s
# [CV 5/5] END activation=relu, alpha=0.01, hidden_layer_sizes=(496, 32, 16), learning_rate=adaptive, max_iter=750, solver=sgd;, score=0.911 total time=  22.4s
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.001, 0.01],
#                          'hidden_layer_sizes': [(496, 32, 16)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'max_iter': [750], 'solver': ['adam', 'sgd']},
#              scoring='accuracy', verbose=3)

# %%
best_params = grid_search_lda.best_params_
print("Best Parameters:", best_params)

with open('../models/mlp/lda.csv', 'w') as f:
    json.dump(best_params, f)

# Get the best model
best_mlp = grid_search_lda.best_estimator_

joblib.dump(best_mlp, "../models/mlp/lda.pkl")

# Print mean validation score for the best model
best_score = grid_search_lda.best_score_
print("Best Model Validation Score:", best_score)

# Predict on the test set
y_pred_mlp_lda = best_mlp.predict(X_test_lda)

# Calculate accuracy on the test set
accuracy_lda = accuracy_score(y_test, y_pred_mlp_lda)
print("Test Accuracy:", accuracy_lda)
# Out:
# Best Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (496, 32, 16), 'learning_rate': 'constant', 'max_iter': 750, 'solver': 'sgd'}
# Best Model Validation Score: 0.9131459520953641
# Test Accuracy: 0.5165816326530612

# %%
pd.DataFrame(y_pred_mlp_lda, columns=["y_pred"]).to_csv("../results/mlp/lda.csv")
